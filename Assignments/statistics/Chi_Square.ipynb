# %% [markdown]
# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats

sample_mean = 50
sample_std = 5
sample_size = 100
confidence_level = 0.95

# Calculate the standard error of the mean
standard_error = sample_std/ (sample_size ** 0.5)

# Calculate the margin of error
margin_of_error = stats.t.ppf((1 + confidence_level) / 2, sample_size - 1) * standard_error

lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Print the confidence interval
print("The 95% confidence interval is ({:.2f}, {:.2f}).".format(lower_bound, upper_bound))
print('''We can say with 95% confidence that the true population mean falls within the range of 48.36 to 51.64, based on the sample data with a mean of 50 and a standard deviation of 5.''')
# Out:
# The 95% confidence interval is (49.01, 50.99).
# We can say with 95% confidence that the true population mean falls within the range of 48.36 to 51.64, based on the sample data with a mean of 50 and a standard deviation of 5.

# %% [markdown]
# Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# brown. Use Python to perform the test with a significance level of 0.05.

# %% [markdown]
# Null hypothesis (H0): The observed distribution of colors of M&Ms in a bag matches the expected distribution.
# Alternative hypothesis (H1): The observed distribution of colors of M&Ms in a bag does not match the expected distribution.

# %%
import numpy as np
import scipy.stats as stats

# Set the observed frequencies of colors
observed_freq = np.array([40, 30, 35, 15, 20, 60])

# Set the expected frequencies of colors
expected_freq = np.array([0.2, 0.2, 0.2, 0.1, 0.1, 0.2]) * 200

# Calculate the chi-square test statistic and p-value
chi_stat,p_val = stats.chisquare(observed_freq, expected_freq)

# Print the results
print('Chi Square statistic:',chi_stat), print('P-Value:',p_val)

# Compare the p-value to the significance level
alpha = 0.05
if p_val < alpha:
    print("The observed distribution of colors of M&Ms in a bag does not match the expected distribution.")
else:
    print("The observed distribution of colors of M&Ms in a bag matches the expected distribution.")
# Out:
# Chi Square statistic: 14.375
# P-Value: 0.013394899560007922
# The observed distribution of colors of M&Ms in a bag does not match the expected distribution.

# %% [markdown]
# ![Screenshot 2023-03-20 at 12.26.37.png](attachment:b981777d-b080-440a-8934-6132c02e821d.png)

# %%
from scipy.stats import chi2_contingency

observed = [[20, 15], [10, 25], [15, 20]]
chi2_stat, p_val, dof, expected = chi2_contingency(observed)
print("Chi-square statistic:", chi2_stat)
print("p-value:", p_val)
# Out:
# Chi-square statistic: 5.833333333333334
# p-value: 0.05411376622282158

# %% [markdown]
# The chi-square statistic is 5.89 with a corresponding p-value of 0.0522. Since the p-value is greater than the commonly used significance level of 0.05, we fail to reject the null hypothesis that there is no association between the two categorical variables (i.e., the outcomes and the groups). In other words, there is not enough evidence to conclude that the distribution of outcomes differs significantly between the two groups.

# %% [markdown]
# Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
# smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
# population who smoke.

# %%
import statsmodels.stats.proportion as smprop

n = 500  # total population
num_smokers = 60  # number of smokers
conf_level = 0.95  # confidence level

lower, upper = smprop.proportion_confint(num_smokers, n, alpha=1-conf_level)

print(f"95% Confidence interval: ({lower:.4f}, {upper:.4f})")
# Out:
# 95% Confidence interval: (0.0915, 0.1485)

# %% [markdown]
# Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats

sample_mean = 75
sample_std = 12
sample_size = 100
confidence_level = 0.90

# Calculate the standard error of the mean
standard_error = sample_std/ (sample_size ** 0.5)

# Calculate the margin of error
margin_of_error = stats.t.ppf((1 + confidence_level) / 2, sample_size - 1) * standard_error

lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Print the confidence interval
print("The 95% confidence interval is ({:.2f}, {:.2f}).".format(lower_bound, upper_bound))
print(f'''We can say with 95% confidence that the true population mean falls within the range of {round(lower_bound,2)} to {round(upper_bound,2)}, 
based on the sample data with a mean of {sample_mean} and a standard deviation of {sample_std}.''')
# Out:
# The 95% confidence interval is (73.01, 76.99).
# We can say with 95% confidence that the true population mean falls within the range of 73.01 to 76.99,
# based on the sample data with a mean of 75 and a standard deviation of 12.

# %% [markdown]
# Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

df = 10 
x = np.linspace(0, 25, 500)
y = chi2.pdf(x, df)
fig, ax = plt.subplots()
ax.plot(x, y)

# Shade the area corresponding to a chi-square statistic of 15
x_shade = np.linspace(15, 25, 100)
y_shade = chi2.pdf(x_shade, df)
ax.fill_between(x_shade, y_shade, 0, alpha=0.5)

ax.set_xlabel("Chi-square statistic")
ax.set_ylabel("Probability density")
ax.set_title("Chi-square distribution with 10 degrees of freedom")

plt.show()

# %% [markdown]
# Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.

# %%
import math
n = 1000
x = 520
p = x / n

# z-score for 99% confidence level
z = 2.576

# margin of error
moe = z * math.sqrt(p * (1 - p) / n)

lower = p - moe
upper = p + moe

print(f"The 99% confidence interval is ({lower:.3f}, {upper:.3f})")
# Out:
# The 99% confidence interval is (0.479, 0.561)

# %% [markdown]
# Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# expected frequencies of a fair coin. Use a significance level of 0.05.

# %% [markdown]
# The null hypothesis (H0) is that the coin is fair, meaning that the probability of getting heads and tails is 0.5 each.
#
# The alternative hypothesis (Ha) is that the coin is biased towards tails, meaning that the probability of getting tails is greater than 0.5.

# %%
import numpy as np

# observed frequencies
observed = np.array([55, 45])

# expected frequencies (assuming a fair coin)
expected = np.array([50, 50])

statistic, pvalue = stats.chisquare(observed, expected)

# print the results
print("Chi-square test statistic:", statistic)
print("p-value:", pvalue)
# Out:
# Chi-square test statistic: 1.0
# p-value: 0.31731050786291115

# %% [markdown]
# Based on the results of the chi-square goodness of fit test, we do not have sufficient evidence to conclude that the coin is biased towards tails. We fail to reject the null hypothesis that the coin is fair.

# %% [markdown]
# Q9. A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis. Use a significance level of 0.05.

# %% [markdown]
# ![1.png](attachment:6fac1435-aad5-4877-9061-d28264964cb2.png)

# %% [markdown]
# The null hypothesis (H0) is that there is no association between smoking status and lung cancer diagnosis.
#
# The alternative hypothesis (Ha) is that there is a significant association between smoking status and lung cancer diagnosis.

# %%
import numpy as np
from scipy.stats import chi2_contingency

observed = np.array([[60, 140], [30, 170]])
alpha = 0.05
# conduct the chi-square test for independence
statistic, pvalue, dof, expected = chi2_contingency(observed)

# print the results
print("Chi-square test statistic:", statistic)
print("p-value:", pvalue)
if pvalue < alpha:
    print('\nH0 is rejected. This means that there is a significant association between smoking status and lung cancer diagnosis.')
else:
    print('We failed to reject H0. This means that there is no association between smoking status and lung cancer diagnosis.')
# Out:
# Chi-square test statistic: 12.057347670250895
# p-value: 0.0005158863863703744
#
# H0 is rejected. This means that there is a significant association between smoking status and lung cancer diagnosis.

# %% [markdown]
# Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark
# chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from
# the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the
# contingency table below. Conduct a chi-square test for independence to determine if there is a significant
# association between chocolate preference and country of origin. Use a significance level of 0.01.

# %% [markdown]
# ![Screenshot 2023-03-20 at 13.47.02.png](attachment:5f55e487-e688-43bc-a1dc-90676fa5e0ef.png)

# %% [markdown]
# H0: There is no significant association between chocolate preference and country of origin.
#
# Ha: There is a significant association between chocolate preference and country of origin.

# %%
import numpy as np
from scipy.stats import chi2_contingency

observed = np.array([[200, 150, 150], [225, 175, 100]])
alpha = 0.01
# conduct the chi-square test for independence
statistic, pvalue, dof, expected = chi2_contingency(observed)

# print the results
print("Chi-square test statistic:", statistic)
print("p-value:", pvalue)
if pvalue < alpha:
    print('\nH0 is rejected. This means that there is a significant association between chocolate preference and country of origin.')
else:
    print('\nWe failed to reject H0. This means that there is no significant association between chocolate preference and country of origin.')
# Out:
# Chi-square test statistic: 13.393665158371041
# p-value: 0.0012348168997745918
#
# H0 is rejected. This means that there is a significant association between chocolate preference and country of origin.

# %% [markdown]
# Q11. A random sample of 30 people was selected from a population with an unknown mean and standard
# deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
# Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
# significance level of 0.05.

# %% [markdown]
# Null Hypothesis (H0): The population mean is equal to 70.
#
# Alternative Hypothesis (H1): The population mean is significantly different from 70.

# %% [markdown]
# t = (x̄ - μ) / (s / √n)
#
# where x̄ is the sample mean, μ is the population mean (in this case, 70), s is the sample standard deviation, and n is the sample size.
#
# Substituting the values given in the question:
#
# t = (72 - 70) / (10 / √30)
#
# t = 1.095
#
# Using a t-distribution table with 29 degrees of freedom (df = n - 1), we find the critical values for a two-tailed test with a significance level of 0.05 to be ±2.045.
#
# Since our calculated t-value (1.095) is within the range of -2.045 to 2.045, we fail to reject the null hypothesis. We do not have enough evidence to conclude that the population mean is significantly different from 70 at a 0.05 level of significance.
